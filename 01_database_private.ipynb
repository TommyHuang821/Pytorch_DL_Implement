# %% [markdown]
# # 深度學習Pytorch手把手實作-資料庫: 私有資料庫存取方式
#
# <br>**<font color = blue size=4 face=雅黑>1. 當資料為結構資料</font>**<br/>
# <br>**<font color = blue size=4 face=雅黑>2. 當資料為非結構資料(圖像)</font>**<br/>
# ___

# %% [markdown]
# <br>**<font color = Blue size=5>1. 當資料為結構資料</font>**<br/>
#
# ><font color = black size=4>當資料為結構資料，有很多種儲存格式，例如txt, xml, json, pickle, csv,...等，但不論是什麼格式只要能讀進電腦整理成最終要進行模型訓練的型態即可。</font>
#
#
# <br><font color = black size=4>在今天課程，我們使用IRIS data當作私有資料範例，這邊我已經將iris.data改成csv資料格式(iris.csv)</font><br/>
# <font color = black size=4>iris.csv存放路徑為: [/dataset/iris.csv](./dataset/iris.csv)，我們用excel將檔案打開如下：</font>
# <img src="Image/irisdata.png" width="40%">
#
#
# <br><font color = black size=4>這邊我們使用numpy模組將csv讀到電腦內，但實際上不一定要用numpy，用你覺得方便的方法即可。</font><br/>
# <br><font color = black size=4>因為此csv內有文字格式，所以我們用str方式進行存取</font><br/>

# %%
import numpy as np
csv_iris_filepath = './dataset/iris.csv'
csvdata_iris = np.loadtxt(csv_iris_filepath,dtype=np.str, delimiter=',')
# print幾筆資料出來看
print(csvdata_iris[0:150:20,:])
# Out:
# [['5.1' '3.5' '1.4' '0.2' 'Iris-setosa']
#  ['5.4' '3.4' '1.7' '0.2' 'Iris-setosa']
#  ['5.0' '3.5' '1.3' '0.3' 'Iris-setosa']
#  ['5.0' '2.0' '3.5' '1.0' 'Iris-versicolor']
#  ['5.5' '2.4' '3.8' '1.1' 'Iris-versicolor']
#  ['6.3' '3.3' '6.0' '2.5' 'Iris-virginica']
#  ['6.9' '3.2' '5.7' '2.3' 'Iris-virginica']
#  ['6.7' '3.1' '5.6' '2.4' 'Iris-virginica']]

# %% [markdown]
# <font color = black size=4>我們將文字的nump array轉換成float格式，且將類別歸屬轉換成量化數字</font>
# ><font color = blue size=3>Iris-setosa為類別0<br/>
# <font color = blue size=3>Iris-versicolor為類別1<br/>
# <font color = blue size=3>Iris-virginica為類別2<br/>

# %%
label_names=['Iris-setosa','Iris-versicolor','Iris-virginica']
x_iris=[]
y =[]
for line in csvdata_iris:
    tmp_data = []
    for tmp in line:
        if tmp in label_names:
            if tmp == 'Iris-setosa':
                y.append(0)
            elif tmp == 'Iris-versicolor':
                y.append(1)
            elif tmp == 'Iris-virginica':
                y.append(2)
        else:
            tmp_data.append(np.float(tmp))
    x_iris.append(tmp_data)

x_iris = np.array(x_iris)
y = np.array(y)
print(x_iris[0:150:20,:])
print(y[0:150:15])
# Out:
# [[5.1 3.5 1.4 0.2]
#  [5.4 3.4 1.7 0.2]
#  [5.  3.5 1.3 0.3]
#  [5.  2.  3.5 1. ]
#  [5.5 2.4 3.8 1.1]
#  [6.3 3.3 6.  2.5]
#  [6.9 3.2 5.7 2.3]
#  [6.7 3.1 5.6 2.4]]
# [0 0 0 0 1 1 1 2 2 2]

# %% [markdown]
# <font color = black size=4> 整理成numpy array後，看需不需要在儲存成numpy格式、json格式或是pickle格式，讓之後要訓練模型的時候可以省去這樣的步驟。但如果覺得這樣的處理很快不需要再額外存取就每一次訓練都執行一次這樣的前處理。</font><br>
# ><font color = red size=4> 建議額外儲存，因為當你的資料有一萬筆，這時候前處理真的很花時間</font><br>
#
# <font color = black size=4>我們這邊用numpy做為資料儲存，如下</font><br>

# %%
np.save("./dataset/iris_x.npy", x_iris)
np.save("./dataset/iris_y.npy", y)

x = np.load( "./dataset/iris_x.npy" )
y = np.load( "./dataset/iris_y.npy" )
print(x[0:150:20,:])
print(y[0:150:20])
# Out:
# [[5.1 3.5 1.4 0.2]
#  [5.4 3.4 1.7 0.2]
#  [5.  3.5 1.3 0.3]
#  [5.  2.  3.5 1. ]
#  [5.5 2.4 3.8 1.1]
#  [6.3 3.3 6.  2.5]
#  [6.9 3.2 5.7 2.3]
#  [6.7 3.1 5.6 2.4]]
# [0 0 0 1 1 2 2 2]

# %% [markdown]
# <br>**<font color = Blue size=5>2. 當資料為非結構資料(圖像)</font>**<br/>
#
# ><br>**<font color = black size=4>當資料為自有且非結構資料的時候，通常我們不會一次將資料全部都讀到記憶體內，因為你的資料可能有幾萬張圖片或是幾百萬張，例如ImageNet這樣的資料庫</font>**<br/>
# <br>**<font color = black size=4>所以我們通常只會處理資料的路徑，將所有圖片的路徑檔案都寫入一個你方便讀取的格式，之後在pytorch內我們只需要在pytorch模組database內的init中將這個格式讀取出來就好。
# 所以此部分我們只簡單介紹一般我們怎麼對這些資料做處理</font>**<br/>
#
# <br>**<font color = black size=4>此範例我們用kaggle內別人整理的圖像Car Brands Images</font>**<br/>
# Car Brands Images dataset link: :https://www.kaggle.com/yamaerenay/100-images-of-top-50-car-brands
#
# <br><font color = black size=3>Car Brands Images資料集載下來有圖像檔案和一個meta資訊(用.csv表示)</font><br/>
#
# <img src="Image/car_file.png" width="80%">
#
# <br><font color = Red size=4>此資料集目的是要依據圖像訊息判斷此圖是屬於高級車種(豪車)還是一般車種</font><br/>
# <br><font color = black size=3>所以我們需要利用資料庫提供的meta訊息來歸類高級車和一般車</font><br/>
# #### companies.csv的meta information讀取，這邊我們也是用numpy做讀取動作

# %%
import numpy as np
csv_filename='./dataset/kaggle/CarBrandsImages/companies.csv'
csvdata = np.loadtxt(csv_filename,dtype=np.str, delimiter=',')
print(csvdata[0:3,:])
# Out:
# [['rank' 'logo_link' 'origin' 'name' 'segment']
#  ['1' 'https://www.carlogos.org/car-logos/toyota-logo.png' 'Japan'
#   'Toyota' 'Mass-Market Cars']
#  ['2' 'https://www.carlogos.org/car-logos/honda-logo.png' 'Japan' 'Honda'
#   'Mass-Market Cars']]

# %% [markdown]
# ### 根據companies.csv的meta information進行處理
#
# 50個資料夾
#
# >依據origin可分成
# United States、Germany、Italy、Sweden、United Kingdom、South Korea、France七個國家
#
# >依據segment可分成
# Mass-Market Cars;
# Luxury Vehicles;
# Sport Utility Vehicles;
# Luxury Sports Cars;
# Pickup Trucks;
# Ultra-luxury Cars;
# Performance Cars;
# Luxury Sport Utility Vehicles;
# Luxury Electric Vehicles;
# Pickup Trucks, Vans;
# Super Luxury Sports Cars;
# Luxury Supercars;
# Small Cars;
# Luxury Small Cars;
# Automobiles;
# Economy Cars;
# Vehicles;
#
# <br><font color = Red size=4>應用分成一般車 (類別為0)和豪車(類別為1)兩種</font><br/>
#
# <br><font color = black size=4>一般車:
# Mass-Market Cars;
# Pickup Trucks;
# Pickup Trucks;
# Small Cars;
# Automobiles;
# Economy Cars;
# Vehicles; </font><br/>
# <br><font color = black size=4>豪車:
# Luxury Vehicles;
# Sport Utility Vehicles;
# Luxury Sports Cars;
# Ultra-luxury Cars;
# Performance Cars;
# Luxury Sport Utility Vehicles;
# Luxury Electric Vehicles;
# Super Luxury Sports Cars;
# Luxury Supercars;
# Luxury Small Cars; </font><br/>

# %%
massmark = ['Mass-Market Cars','Pickup Trucks','Pickup Trucks', 'Small Cars','Automobiles', 'Economy Cars', 'Vehicles']  
luxury = ['Luxury Vehicles', 'Sport Utility Vehicles','Luxury Sports Cars','Ultra-luxury Cars', 'Performance Cars',
        'Luxury Sport Utility Vehicles','Luxury Electric Vehicles','Super Luxury Sports Cars','Luxury Supercars','Luxury Small Cars']
import os
import numpy as np
imagepaths, labels=[],[]
for dirname, _, filenames in os.walk('./dataset/kaggle/CarBrandsImages/imgs'):
    if len(filenames)!=0:
        brand = dirname.split("\\")[-1]
        pos=np.where(csvdata[:,3]== brand)[0]
        segment = csvdata[pos,4][0]
        if segment in massmark:
            label = 0
        elif segment in luxury:
            label = 1
        print('{} : {}'.format(brand, label))
        for filename in filenames:
            imagepaths.append(os.path.join(dirname, filename))
            labels.append(label)
# Out:
# Acura : 1
# Alfa Romeo : 1
# Aston Martin : 1
# Audi : 1
# Bentley : 1
# BMW : 1
# Bugatti : 1
# Buick : 0
# Cadillac : 1
# Chevrolet : 0
# Chrysler : 1
# Citroen : 0
# Daewoo : 0
# Dodge : 1
# Ferrari : 1
# Fiat : 0
# Ford : 0
# Genesis : 1
# GMC : 0
# Honda : 0
# Hudson : 0
# Hyundai : 0
# Infiniti : 1
# Jaguar : 1
# Jeep : 1
# Kia : 0
# Land Rover : 1
# Lexus : 1
# Lincoln : 1
# Maserati : 1
# Mazda : 0
# Mercedes-Benz : 1
# MG : 0
# Mini : 1
# Mitsubishi : 0
# Nissan : 0
# Oldsmobile : 0
# Peugeot : 0
# Pontiac : 1
# Porsche : 1
# Ram Trucks : 0
# Renault : 0
# Saab : 0
# Studebaker : 0
# Subaru : 0
# Suzuki : 0
# Tesla : 1
# Toyota : 0
# Volkswagen : 0
# Volvo : 1

# %% [markdown]
# <br><font color = black size=4>將filepath和label儲存成json檔</font><br/>

# %%
import json
data={}
data['imagepaths']=imagepaths
data['labels']=labels
with open('./dataset/kaggle/CarBrandsImages/carbrand.json', 'w', newline='') as jsonfile:
    json.dump(data, jsonfile)

# %% [markdown]
# <br><font color = black size=4>讀取JSON檔案</font><br/>

# %%
with open('./dataset/kaggle/CarBrandsImages/carbrand.json') as jsonfile:
    data_load = json.load(jsonfile)
for imagepath,label in zip(data_load['imagepaths'],data_load['labels']):
    print("filepath:{}, label: {}".format(imagepath,label))
# Out:
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Acura\Acura_000.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Acura\Acura_001.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Acura\Acura_002.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Acura\Acura_003.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Acura\Acura_004.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Acura\Acura_005.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Acura\Acura_006.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Acura\Acura_007.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Acura\Acura_008.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Acura\Acura_009.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Acura\Acura_010.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Acura\Acura_011.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Acura\Acura_012.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Acura\Acura_013.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Acura\Acura_014.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Acura\Acura_015.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Acura\Acura_016.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Acura\Acura_017.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Acura\Acura_018.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Acura\Acura_019.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Acura\Acura_020.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Acura\Acura_021.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Acura\Acura_022.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Acura\Acura_023.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Acura\Acura_024.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Acura\Acura_025.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Acura\Acura_026.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Acura\Acura_027.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Acura\Acura_028.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Acura\Acura_029.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Acura\Acura_030.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Acura\Acura_031.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Acura\Acura_032.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Acura\Acura_033.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Acura\Acura_034.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Acura\Acura_035.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Acura\Acura_036.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Acura\Acura_037.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Acura\Acura_038.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Acura\Acura_039.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Acura\Acura_040.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Acura\Acura_041.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Acura\Acura_042.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Acura\Acura_043.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Acura\Acura_044.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Acura\Acura_045.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Acura\Acura_046.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Acura\Acura_047.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Acura\Acura_048.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Acura\Acura_049.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Acura\Acura_050.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Acura\Acura_051.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Acura\Acura_052.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Acura\Acura_053.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Acura\Acura_054.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Acura\Acura_055.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Acura\Acura_056.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Acura\Acura_057.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Acura\Acura_058.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Acura\Acura_059.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Acura\Acura_060.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Acura\Acura_061.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Acura\Acura_062.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Acura\Acura_063.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Acura\Acura_064.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Acura\Acura_065.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Acura\Acura_066.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Acura\Acura_067.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Acura\Acura_068.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Acura\Acura_069.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Acura\Acura_070.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Acura\Acura_071.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Acura\Acura_072.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Acura\Acura_073.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Acura\Acura_074.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Acura\Acura_075.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Acura\Acura_076.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Acura\Acura_077.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Acura\Acura_078.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Acura\Acura_079.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Acura\Acura_080.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Acura\Acura_081.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Acura\Acura_082.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Acura\Acura_083.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Acura\Acura_084.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Acura\Acura_085.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Acura\Acura_086.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Acura\Acura_087.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Acura\Acura_088.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Acura\Acura_089.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Alfa Romeo\Alfa Romeo_000.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Alfa Romeo\Alfa Romeo_001.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Alfa Romeo\Alfa Romeo_002.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Alfa Romeo\Alfa Romeo_003.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Alfa Romeo\Alfa Romeo_004.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Alfa Romeo\Alfa Romeo_005.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Alfa Romeo\Alfa Romeo_006.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Alfa Romeo\Alfa Romeo_007.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Alfa Romeo\Alfa Romeo_008.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Alfa Romeo\Alfa Romeo_009.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Alfa Romeo\Alfa Romeo_010.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Alfa Romeo\Alfa Romeo_011.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Alfa Romeo\Alfa Romeo_012.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Alfa Romeo\Alfa Romeo_013.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Alfa Romeo\Alfa Romeo_014.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Alfa Romeo\Alfa Romeo_015.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Alfa Romeo\Alfa Romeo_016.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Alfa Romeo\Alfa Romeo_017.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Alfa Romeo\Alfa Romeo_018.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Alfa Romeo\Alfa Romeo_019.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Alfa Romeo\Alfa Romeo_020.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Alfa Romeo\Alfa Romeo_021.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Alfa Romeo\Alfa Romeo_022.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Alfa Romeo\Alfa Romeo_023.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Alfa Romeo\Alfa Romeo_024.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Alfa Romeo\Alfa Romeo_025.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Alfa Romeo\Alfa Romeo_026.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Alfa Romeo\Alfa Romeo_027.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Alfa Romeo\Alfa Romeo_028.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Alfa Romeo\Alfa Romeo_029.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Alfa Romeo\Alfa Romeo_030.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Alfa Romeo\Alfa Romeo_031.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Alfa Romeo\Alfa Romeo_032.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Alfa Romeo\Alfa Romeo_033.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Alfa Romeo\Alfa Romeo_034.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Alfa Romeo\Alfa Romeo_035.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Alfa Romeo\Alfa Romeo_036.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Alfa Romeo\Alfa Romeo_037.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Alfa Romeo\Alfa Romeo_038.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Alfa Romeo\Alfa Romeo_039.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Alfa Romeo\Alfa Romeo_040.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Alfa Romeo\Alfa Romeo_041.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Alfa Romeo\Alfa Romeo_042.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Alfa Romeo\Alfa Romeo_043.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Alfa Romeo\Alfa Romeo_044.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Alfa Romeo\Alfa Romeo_045.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Alfa Romeo\Alfa Romeo_046.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Alfa Romeo\Alfa Romeo_047.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Alfa Romeo\Alfa Romeo_048.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Alfa Romeo\Alfa Romeo_049.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Alfa Romeo\Alfa Romeo_050.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Alfa Romeo\Alfa Romeo_051.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Alfa Romeo\Alfa Romeo_052.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Alfa Romeo\Alfa Romeo_053.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Alfa Romeo\Alfa Romeo_054.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Alfa Romeo\Alfa Romeo_055.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Alfa Romeo\Alfa Romeo_056.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Alfa Romeo\Alfa Romeo_057.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Alfa Romeo\Alfa Romeo_058.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Alfa Romeo\Alfa Romeo_059.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Alfa Romeo\Alfa Romeo_060.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Alfa Romeo\Alfa Romeo_061.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Alfa Romeo\Alfa Romeo_062.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Alfa Romeo\Alfa Romeo_063.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Alfa Romeo\Alfa Romeo_064.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Alfa Romeo\Alfa Romeo_065.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Alfa Romeo\Alfa Romeo_066.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Alfa Romeo\Alfa Romeo_067.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Alfa Romeo\Alfa Romeo_068.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Alfa Romeo\Alfa Romeo_069.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Alfa Romeo\Alfa Romeo_070.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Alfa Romeo\Alfa Romeo_071.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Alfa Romeo\Alfa Romeo_072.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Alfa Romeo\Alfa Romeo_073.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Alfa Romeo\Alfa Romeo_074.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Alfa Romeo\Alfa Romeo_075.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Alfa Romeo\Alfa Romeo_076.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Alfa Romeo\Alfa Romeo_077.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Alfa Romeo\Alfa Romeo_078.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Alfa Romeo\Alfa Romeo_079.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Alfa Romeo\Alfa Romeo_080.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Alfa Romeo\Alfa Romeo_081.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Alfa Romeo\Alfa Romeo_082.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Alfa Romeo\Alfa Romeo_083.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Alfa Romeo\Alfa Romeo_084.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Alfa Romeo\Alfa Romeo_085.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Alfa Romeo\Alfa Romeo_086.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Alfa Romeo\Alfa Romeo_087.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Alfa Romeo\Alfa Romeo_088.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Aston Martin\Aston Martin_000.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Aston Martin\Aston Martin_001.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Aston Martin\Aston Martin_002.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Aston Martin\Aston Martin_003.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Aston Martin\Aston Martin_004.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Aston Martin\Aston Martin_005.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Aston Martin\Aston Martin_006.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Aston Martin\Aston Martin_007.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Aston Martin\Aston Martin_008.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Aston Martin\Aston Martin_009.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Aston Martin\Aston Martin_010.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Aston Martin\Aston Martin_011.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Aston Martin\Aston Martin_012.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Aston Martin\Aston Martin_013.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Aston Martin\Aston Martin_014.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Aston Martin\Aston Martin_015.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Aston Martin\Aston Martin_016.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Aston Martin\Aston Martin_017.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Aston Martin\Aston Martin_018.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Aston Martin\Aston Martin_019.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Aston Martin\Aston Martin_020.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Aston Martin\Aston Martin_021.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Aston Martin\Aston Martin_022.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Aston Martin\Aston Martin_023.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Aston Martin\Aston Martin_024.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Aston Martin\Aston Martin_025.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Aston Martin\Aston Martin_026.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Aston Martin\Aston Martin_027.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Aston Martin\Aston Martin_028.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Aston Martin\Aston Martin_029.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Aston Martin\Aston Martin_030.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Aston Martin\Aston Martin_031.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Aston Martin\Aston Martin_032.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Aston Martin\Aston Martin_033.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Aston Martin\Aston Martin_034.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Aston Martin\Aston Martin_035.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Aston Martin\Aston Martin_036.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Aston Martin\Aston Martin_037.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Aston Martin\Aston Martin_038.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Aston Martin\Aston Martin_039.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Aston Martin\Aston Martin_040.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Aston Martin\Aston Martin_041.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Aston Martin\Aston Martin_042.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Aston Martin\Aston Martin_043.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Aston Martin\Aston Martin_044.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Aston Martin\Aston Martin_045.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Aston Martin\Aston Martin_046.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Aston Martin\Aston Martin_047.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Aston Martin\Aston Martin_048.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Aston Martin\Aston Martin_049.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Aston Martin\Aston Martin_050.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Aston Martin\Aston Martin_051.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Aston Martin\Aston Martin_052.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Aston Martin\Aston Martin_053.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Aston Martin\Aston Martin_054.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Aston Martin\Aston Martin_055.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Aston Martin\Aston Martin_056.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Aston Martin\Aston Martin_057.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Aston Martin\Aston Martin_058.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Aston Martin\Aston Martin_059.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Aston Martin\Aston Martin_060.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Aston Martin\Aston Martin_061.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Aston Martin\Aston Martin_062.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Aston Martin\Aston Martin_063.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Aston Martin\Aston Martin_064.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Aston Martin\Aston Martin_065.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Aston Martin\Aston Martin_066.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Aston Martin\Aston Martin_067.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Aston Martin\Aston Martin_068.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Aston Martin\Aston Martin_069.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Aston Martin\Aston Martin_070.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Aston Martin\Aston Martin_071.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Aston Martin\Aston Martin_072.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Aston Martin\Aston Martin_073.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Aston Martin\Aston Martin_074.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Aston Martin\Aston Martin_075.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Aston Martin\Aston Martin_076.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Aston Martin\Aston Martin_077.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Aston Martin\Aston Martin_078.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Aston Martin\Aston Martin_079.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Aston Martin\Aston Martin_080.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Aston Martin\Aston Martin_081.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Aston Martin\Aston Martin_082.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Aston Martin\Aston Martin_083.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Aston Martin\Aston Martin_084.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Aston Martin\Aston Martin_085.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Aston Martin\Aston Martin_086.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Aston Martin\Aston Martin_087.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Aston Martin\Aston Martin_088.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Aston Martin\Aston Martin_089.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Aston Martin\Aston Martin_090.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Audi\Audi_000.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Audi\Audi_001.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Audi\Audi_002.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Audi\Audi_003.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Audi\Audi_004.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Audi\Audi_005.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Audi\Audi_006.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Audi\Audi_007.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Audi\Audi_008.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Audi\Audi_009.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Audi\Audi_010.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Audi\Audi_011.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Audi\Audi_012.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Audi\Audi_013.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Audi\Audi_014.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Audi\Audi_015.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Audi\Audi_016.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Audi\Audi_017.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Audi\Audi_018.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Audi\Audi_019.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Audi\Audi_020.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Audi\Audi_021.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Audi\Audi_022.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Audi\Audi_023.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Audi\Audi_024.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Audi\Audi_025.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Audi\Audi_026.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Audi\Audi_027.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Audi\Audi_028.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Audi\Audi_029.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Audi\Audi_030.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Audi\Audi_031.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Audi\Audi_032.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Audi\Audi_033.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Audi\Audi_034.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Audi\Audi_035.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Audi\Audi_036.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Audi\Audi_037.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Audi\Audi_038.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Audi\Audi_039.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Audi\Audi_040.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Audi\Audi_041.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Audi\Audi_042.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Audi\Audi_043.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Audi\Audi_044.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Audi\Audi_045.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Audi\Audi_046.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Audi\Audi_047.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Audi\Audi_048.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Audi\Audi_049.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Audi\Audi_050.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Audi\Audi_051.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Audi\Audi_052.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Audi\Audi_053.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Audi\Audi_054.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Audi\Audi_055.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Audi\Audi_056.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Audi\Audi_057.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Audi\Audi_058.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Audi\Audi_059.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Audi\Audi_060.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Audi\Audi_061.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Audi\Audi_062.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Audi\Audi_063.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Audi\Audi_064.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Audi\Audi_065.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Audi\Audi_066.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Audi\Audi_067.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Audi\Audi_068.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Audi\Audi_069.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Audi\Audi_070.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Audi\Audi_071.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Audi\Audi_072.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Audi\Audi_073.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Audi\Audi_074.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Audi\Audi_075.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Audi\Audi_076.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Audi\Audi_077.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Audi\Audi_078.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Audi\Audi_079.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Audi\Audi_080.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Audi\Audi_081.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Audi\Audi_082.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Audi\Audi_083.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Audi\Audi_084.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Audi\Audi_085.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bentley\Bentley_000.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bentley\Bentley_001.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bentley\Bentley_002.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bentley\Bentley_003.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bentley\Bentley_004.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bentley\Bentley_005.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bentley\Bentley_006.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bentley\Bentley_007.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bentley\Bentley_008.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bentley\Bentley_009.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bentley\Bentley_010.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bentley\Bentley_011.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bentley\Bentley_012.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bentley\Bentley_013.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bentley\Bentley_014.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bentley\Bentley_015.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bentley\Bentley_016.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bentley\Bentley_017.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bentley\Bentley_018.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bentley\Bentley_019.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bentley\Bentley_020.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bentley\Bentley_021.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bentley\Bentley_022.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bentley\Bentley_023.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bentley\Bentley_024.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bentley\Bentley_025.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bentley\Bentley_026.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bentley\Bentley_027.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bentley\Bentley_028.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bentley\Bentley_029.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bentley\Bentley_030.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bentley\Bentley_031.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bentley\Bentley_032.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bentley\Bentley_033.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bentley\Bentley_034.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bentley\Bentley_035.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bentley\Bentley_036.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bentley\Bentley_037.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bentley\Bentley_038.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bentley\Bentley_039.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bentley\Bentley_040.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bentley\Bentley_041.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bentley\Bentley_042.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bentley\Bentley_043.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bentley\Bentley_044.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bentley\Bentley_045.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bentley\Bentley_046.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bentley\Bentley_047.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bentley\Bentley_048.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bentley\Bentley_049.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bentley\Bentley_050.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bentley\Bentley_051.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bentley\Bentley_052.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bentley\Bentley_053.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bentley\Bentley_054.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bentley\Bentley_055.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bentley\Bentley_056.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bentley\Bentley_057.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bentley\Bentley_058.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bentley\Bentley_059.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bentley\Bentley_060.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bentley\Bentley_061.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bentley\Bentley_062.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bentley\Bentley_063.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bentley\Bentley_064.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bentley\Bentley_065.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bentley\Bentley_066.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bentley\Bentley_067.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bentley\Bentley_068.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bentley\Bentley_069.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bentley\Bentley_070.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bentley\Bentley_071.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bentley\Bentley_072.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bentley\Bentley_073.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bentley\Bentley_074.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bentley\Bentley_075.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bentley\Bentley_076.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bentley\Bentley_077.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bentley\Bentley_078.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bentley\Bentley_079.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bentley\Bentley_080.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bentley\Bentley_081.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bentley\Bentley_082.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bentley\Bentley_083.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bentley\Bentley_084.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bentley\Bentley_085.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bentley\Bentley_086.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bentley\Bentley_087.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bentley\Bentley_088.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bentley\Bentley_089.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bentley\Bentley_090.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\BMW\BMW_000.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\BMW\BMW_001.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\BMW\BMW_002.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\BMW\BMW_003.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\BMW\BMW_004.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\BMW\BMW_005.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\BMW\BMW_006.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\BMW\BMW_007.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\BMW\BMW_008.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\BMW\BMW_009.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\BMW\BMW_010.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\BMW\BMW_011.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\BMW\BMW_012.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\BMW\BMW_013.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\BMW\BMW_014.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\BMW\BMW_015.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\BMW\BMW_016.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\BMW\BMW_017.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\BMW\BMW_018.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\BMW\BMW_019.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\BMW\BMW_020.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\BMW\BMW_021.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\BMW\BMW_022.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\BMW\BMW_023.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\BMW\BMW_024.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\BMW\BMW_025.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\BMW\BMW_026.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\BMW\BMW_027.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\BMW\BMW_028.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\BMW\BMW_029.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\BMW\BMW_030.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\BMW\BMW_031.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\BMW\BMW_032.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\BMW\BMW_033.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\BMW\BMW_034.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\BMW\BMW_035.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\BMW\BMW_036.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\BMW\BMW_037.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\BMW\BMW_038.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\BMW\BMW_039.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\BMW\BMW_040.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\BMW\BMW_041.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\BMW\BMW_042.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\BMW\BMW_043.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\BMW\BMW_044.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\BMW\BMW_045.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\BMW\BMW_046.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\BMW\BMW_047.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\BMW\BMW_048.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\BMW\BMW_049.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\BMW\BMW_050.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\BMW\BMW_051.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\BMW\BMW_052.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\BMW\BMW_053.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\BMW\BMW_054.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\BMW\BMW_055.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\BMW\BMW_056.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\BMW\BMW_057.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\BMW\BMW_058.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\BMW\BMW_059.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\BMW\BMW_060.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\BMW\BMW_061.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\BMW\BMW_062.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\BMW\BMW_063.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\BMW\BMW_064.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\BMW\BMW_065.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\BMW\BMW_066.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\BMW\BMW_067.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\BMW\BMW_068.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\BMW\BMW_069.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\BMW\BMW_070.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\BMW\BMW_071.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\BMW\BMW_072.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\BMW\BMW_073.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\BMW\BMW_074.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\BMW\BMW_075.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\BMW\BMW_076.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\BMW\BMW_077.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\BMW\BMW_078.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\BMW\BMW_079.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\BMW\BMW_080.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\BMW\BMW_081.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\BMW\BMW_082.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\BMW\BMW_083.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bugatti\Bugatti_000.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bugatti\Bugatti_001.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bugatti\Bugatti_002.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bugatti\Bugatti_003.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bugatti\Bugatti_004.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bugatti\Bugatti_005.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bugatti\Bugatti_006.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bugatti\Bugatti_007.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bugatti\Bugatti_008.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bugatti\Bugatti_009.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bugatti\Bugatti_010.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bugatti\Bugatti_011.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bugatti\Bugatti_012.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bugatti\Bugatti_013.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bugatti\Bugatti_014.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bugatti\Bugatti_015.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bugatti\Bugatti_016.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bugatti\Bugatti_017.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bugatti\Bugatti_018.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bugatti\Bugatti_019.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bugatti\Bugatti_020.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bugatti\Bugatti_021.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bugatti\Bugatti_022.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bugatti\Bugatti_023.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bugatti\Bugatti_024.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bugatti\Bugatti_025.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bugatti\Bugatti_026.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bugatti\Bugatti_027.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bugatti\Bugatti_028.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bugatti\Bugatti_029.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bugatti\Bugatti_030.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bugatti\Bugatti_031.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bugatti\Bugatti_032.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bugatti\Bugatti_033.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bugatti\Bugatti_034.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bugatti\Bugatti_035.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bugatti\Bugatti_036.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bugatti\Bugatti_037.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bugatti\Bugatti_038.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bugatti\Bugatti_039.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bugatti\Bugatti_040.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bugatti\Bugatti_041.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bugatti\Bugatti_042.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bugatti\Bugatti_043.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bugatti\Bugatti_044.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bugatti\Bugatti_045.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bugatti\Bugatti_046.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bugatti\Bugatti_047.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bugatti\Bugatti_048.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bugatti\Bugatti_049.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bugatti\Bugatti_050.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bugatti\Bugatti_051.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bugatti\Bugatti_052.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bugatti\Bugatti_053.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bugatti\Bugatti_054.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bugatti\Bugatti_055.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bugatti\Bugatti_056.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bugatti\Bugatti_057.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bugatti\Bugatti_058.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bugatti\Bugatti_059.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bugatti\Bugatti_060.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Bugatti\Bugatti_061.jpg, label: 1
# ...
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Toyota\Toyota_080.jpg, label: 0
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Toyota\Toyota_081.jpg, label: 0
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Toyota\Toyota_082.jpg, label: 0
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Toyota\Toyota_083.jpg, label: 0
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Toyota\Toyota_084.jpg, label: 0
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Toyota\Toyota_085.jpg, label: 0
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Toyota\Toyota_086.jpg, label: 0
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Toyota\Toyota_087.jpg, label: 0
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Toyota\Toyota_088.jpg, label: 0
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Toyota\Toyota_089.jpg, label: 0
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Toyota\Toyota_090.jpg, label: 0
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Toyota\Toyota_091.jpg, label: 0
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volkswagen\Volkswagen_000.jpg, label: 0
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volkswagen\Volkswagen_001.jpg, label: 0
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volkswagen\Volkswagen_002.jpg, label: 0
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volkswagen\Volkswagen_003.jpg, label: 0
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volkswagen\Volkswagen_004.jpg, label: 0
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volkswagen\Volkswagen_005.jpg, label: 0
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volkswagen\Volkswagen_006.jpg, label: 0
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volkswagen\Volkswagen_007.jpg, label: 0
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volkswagen\Volkswagen_008.jpg, label: 0
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volkswagen\Volkswagen_009.jpg, label: 0
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volkswagen\Volkswagen_010.jpg, label: 0
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volkswagen\Volkswagen_011.jpg, label: 0
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volkswagen\Volkswagen_012.jpg, label: 0
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volkswagen\Volkswagen_013.jpg, label: 0
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volkswagen\Volkswagen_014.jpg, label: 0
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volkswagen\Volkswagen_015.jpg, label: 0
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volkswagen\Volkswagen_016.jpg, label: 0
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volkswagen\Volkswagen_017.jpg, label: 0
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volkswagen\Volkswagen_018.jpg, label: 0
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volkswagen\Volkswagen_019.jpg, label: 0
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volkswagen\Volkswagen_020.jpg, label: 0
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volkswagen\Volkswagen_021.jpg, label: 0
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volkswagen\Volkswagen_022.jpg, label: 0
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volkswagen\Volkswagen_023.jpg, label: 0
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volkswagen\Volkswagen_024.jpg, label: 0
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volkswagen\Volkswagen_025.jpg, label: 0
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volkswagen\Volkswagen_026.jpg, label: 0
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volkswagen\Volkswagen_027.jpg, label: 0
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volkswagen\Volkswagen_028.jpg, label: 0
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volkswagen\Volkswagen_029.jpg, label: 0
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volkswagen\Volkswagen_030.jpg, label: 0
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volkswagen\Volkswagen_031.jpg, label: 0
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volkswagen\Volkswagen_032.jpg, label: 0
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volkswagen\Volkswagen_033.jpg, label: 0
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volkswagen\Volkswagen_034.jpg, label: 0
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volkswagen\Volkswagen_035.jpg, label: 0
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volkswagen\Volkswagen_036.jpg, label: 0
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volkswagen\Volkswagen_037.jpg, label: 0
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volkswagen\Volkswagen_038.jpg, label: 0
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volkswagen\Volkswagen_039.jpg, label: 0
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volkswagen\Volkswagen_040.jpg, label: 0
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volkswagen\Volkswagen_041.jpg, label: 0
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volkswagen\Volkswagen_042.jpg, label: 0
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volkswagen\Volkswagen_043.jpg, label: 0
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volkswagen\Volkswagen_044.jpg, label: 0
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volkswagen\Volkswagen_045.jpg, label: 0
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volkswagen\Volkswagen_046.jpg, label: 0
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volkswagen\Volkswagen_047.jpg, label: 0
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volkswagen\Volkswagen_048.jpg, label: 0
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volkswagen\Volkswagen_049.jpg, label: 0
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volkswagen\Volkswagen_050.jpg, label: 0
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volkswagen\Volkswagen_051.jpg, label: 0
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volkswagen\Volkswagen_052.jpg, label: 0
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volkswagen\Volkswagen_053.jpg, label: 0
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volkswagen\Volkswagen_054.jpg, label: 0
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volkswagen\Volkswagen_055.jpg, label: 0
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volkswagen\Volkswagen_056.jpg, label: 0
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volkswagen\Volkswagen_057.jpg, label: 0
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volkswagen\Volkswagen_058.jpg, label: 0
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volkswagen\Volkswagen_059.jpg, label: 0
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volkswagen\Volkswagen_060.jpg, label: 0
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volkswagen\Volkswagen_061.jpg, label: 0
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volkswagen\Volkswagen_062.jpg, label: 0
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volkswagen\Volkswagen_063.jpg, label: 0
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volkswagen\Volkswagen_064.jpg, label: 0
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volkswagen\Volkswagen_065.jpg, label: 0
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volkswagen\Volkswagen_066.jpg, label: 0
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volkswagen\Volkswagen_067.jpg, label: 0
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volkswagen\Volkswagen_068.jpg, label: 0
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volkswagen\Volkswagen_069.jpg, label: 0
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volkswagen\Volkswagen_070.jpg, label: 0
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volkswagen\Volkswagen_071.jpg, label: 0
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volkswagen\Volkswagen_072.jpg, label: 0
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volkswagen\Volkswagen_073.jpg, label: 0
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volkswagen\Volkswagen_074.jpg, label: 0
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volkswagen\Volkswagen_075.jpg, label: 0
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volkswagen\Volkswagen_076.jpg, label: 0
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volkswagen\Volkswagen_077.jpg, label: 0
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volkswagen\Volkswagen_078.jpg, label: 0
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volkswagen\Volkswagen_079.jpg, label: 0
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volkswagen\Volkswagen_080.jpg, label: 0
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volkswagen\Volkswagen_081.jpg, label: 0
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volkswagen\Volkswagen_082.jpg, label: 0
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volkswagen\Volkswagen_083.jpg, label: 0
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volkswagen\Volkswagen_084.jpg, label: 0
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volkswagen\Volkswagen_085.jpg, label: 0
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volkswagen\Volkswagen_086.jpg, label: 0
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volkswagen\Volkswagen_087.jpg, label: 0
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volkswagen\Volkswagen_088.jpg, label: 0
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volkswagen\Volkswagen_089.jpg, label: 0
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volkswagen\Volkswagen_090.jpg, label: 0
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volkswagen\Volkswagen_091.jpg, label: 0
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volkswagen\Volkswagen_092.jpg, label: 0
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volkswagen\Volkswagen_093.jpg, label: 0
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volvo\Volvo_000.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volvo\Volvo_001.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volvo\Volvo_002.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volvo\Volvo_003.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volvo\Volvo_004.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volvo\Volvo_005.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volvo\Volvo_006.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volvo\Volvo_007.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volvo\Volvo_008.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volvo\Volvo_009.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volvo\Volvo_010.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volvo\Volvo_011.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volvo\Volvo_012.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volvo\Volvo_013.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volvo\Volvo_014.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volvo\Volvo_015.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volvo\Volvo_016.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volvo\Volvo_017.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volvo\Volvo_018.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volvo\Volvo_019.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volvo\Volvo_020.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volvo\Volvo_021.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volvo\Volvo_022.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volvo\Volvo_023.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volvo\Volvo_024.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volvo\Volvo_025.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volvo\Volvo_026.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volvo\Volvo_027.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volvo\Volvo_028.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volvo\Volvo_029.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volvo\Volvo_030.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volvo\Volvo_031.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volvo\Volvo_032.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volvo\Volvo_033.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volvo\Volvo_034.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volvo\Volvo_035.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volvo\Volvo_036.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volvo\Volvo_037.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volvo\Volvo_038.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volvo\Volvo_039.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volvo\Volvo_040.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volvo\Volvo_041.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volvo\Volvo_042.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volvo\Volvo_043.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volvo\Volvo_044.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volvo\Volvo_045.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volvo\Volvo_046.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volvo\Volvo_047.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volvo\Volvo_048.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volvo\Volvo_049.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volvo\Volvo_050.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volvo\Volvo_051.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volvo\Volvo_052.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volvo\Volvo_053.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volvo\Volvo_054.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volvo\Volvo_055.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volvo\Volvo_056.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volvo\Volvo_057.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volvo\Volvo_058.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volvo\Volvo_059.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volvo\Volvo_060.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volvo\Volvo_061.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volvo\Volvo_062.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volvo\Volvo_063.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volvo\Volvo_064.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volvo\Volvo_065.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volvo\Volvo_066.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volvo\Volvo_067.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volvo\Volvo_068.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volvo\Volvo_069.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volvo\Volvo_070.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volvo\Volvo_071.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volvo\Volvo_072.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volvo\Volvo_073.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volvo\Volvo_074.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volvo\Volvo_075.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volvo\Volvo_076.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volvo\Volvo_077.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volvo\Volvo_078.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volvo\Volvo_079.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volvo\Volvo_080.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volvo\Volvo_081.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volvo\Volvo_082.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volvo\Volvo_083.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volvo\Volvo_084.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volvo\Volvo_085.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volvo\Volvo_086.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volvo\Volvo_087.jpg, label: 1
# filepath:./dataset/kaggle/CarBrandsImages/imgs\Volvo\Volvo_088.jpg, label: 1
